# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("student_duplicates.csv")
df.head()
# Out:
#    Student_ID             Name  Age  Gender    Department  Semester  \
# 0      STU001        Arjun Rao   19    Male  Data Science         7
# 1      STU002       Meera Nair   22    Male           CSE         4
# 2      STU003  Manish Kulkarni   23    Male         Civil         4
# 3      STU004     Ananya Patel   22  Female           ECE         2
# 4      STU005     Aadhya Verma   22    Male           EEE         2
# ..        ...              ...  ...     ...           ...       ...
# 95     STU096      Kiran Gupta   24    Male          AIML         1
# 96     STU097       Ananya Rao   19  Female           EEE         4
# 97     STU098      Priya Naidu   25  Female           ECE         8
# 98     STU099    Vihaan Sharma   22  Female           EEE         1
# 99     STU100        Rohan Rao   22  Female    Mechanical         4
#
#     Attendance_Percentage  Internal_Marks  CGPA       City Scholarship
# 0                    76.5            49.3  5.90    Chennai          No
# ...

# %%
df.shape
# Out:
# (233, 11)

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 228     True
# 229     True
# 230    False
# 231    False
# 232    False
# Length: 233, dtype: bool

# %%
print(df.duplicated().sum())
# Out:
# 10
