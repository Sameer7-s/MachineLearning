# %%
import seaborn as sns
import cufflinks as cf
import numpy as np

# Enable offline interactive plotting
cf.go_offline()

# Load tips dataset from online
tips = sns.load_dataset("tips")

# Compatibility fix for Cufflinks
np.float64 = float

# Display dataset
print(tips)

# Interactive plot
tips["total_bill"].iplot()%%!
# Out:
#   Cell In[7], line 18
#     tips["total_bill"].iplot()%%!
#                                ^
# SyntaxError: invalid syntax
