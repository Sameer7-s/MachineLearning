# %% [markdown]
# WHY DO WE NEED PANDA

# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# Get a data set

# %%
a = [1,2,3,4,5,6] ## list

# %%
## converting list into a series 
s = pd.Series(a)
s
s[1]
# Out:
# np.int64(2)

# %%
d = {"Aman" : 68, "rohan":34, "Akarsh" : 89}
s = pd.Series(d)
s
# Out:
# Aman      68
# rohan     34
# Akarsh    89
# dtype: int64

# %%
df = pd.DataFrame([d])
df
#creeating a series with lables

# marks = pd.Series(
#     ["Rithvik",49,46.5],
#     index = ["Ram","Ravi","Sam"]
# )
# marks
# Out:
#    Aman  rohan  Akarsh
# 0    68     34      89

# %%
df = pd.DataFrame({
    "Name":["Aman","Riya"],
    "salary":[10000,500000]
})
df 
data = pd.DataFrame({
    "Name":["Sourabh" , "Qaasim"],
    "Salary" : [90000 , 3332242]
})
df = pd.DataFrame(data)
df
# Out:
#       Name   Salary
# 0  Sourabh    90000
# 1   Qaasim  3332242

# %%
df.columns
df.shape
# Out:
# (2, 2)

# %% [markdown]
# LOAD DATA IN CSV FILE

# %%
df = pd.read_csv("employees_100.csv")
df
# Out:
#     employee_id            name    department       city   age salary  \
# 0           184    Swati Kapoor  Data Science    Kolkata  38.0  70719
# 1           154  Kavya Malhotra   engineering     Mumbai   NaN  77058
# 2           171    Manish Desai  Data Science  Hyderabad  23.0  69911
# 3           146        Neha Das   Engineering       Pune  28.0  69993
# 4           145       Isha Nair  Data Science        NaN  32.0  88216
# ..          ...             ...           ...        ...   ...    ...
# 95          161     Nikhil Nair     MARKETING    Chennai  22.0  55740
# 96          172      Neha Desai            HR    Chennai  22.0  52250
# 97          115      Neha Reddy     Marketing    Chennai  43.0    NaN
# 98          193     Priya Nayak            HR        NaN  23.0  56821
# 99          152     Kavya Joshi     Marketing      Delhi  44.0  69499
#
#     experience  performance_score  projects_completed joining_date
# ...

# %%
df.head() ## SHOWS STARTING 5
# Out:
#       Name   Salary
# 0  Sourabh    90000
# 1   Qaasim  3332242

# %%
df.tail()
# Out:
#     employee_id         name department     city   age salary  experience  \
# 95          161  Nikhil Nair  MARKETING  Chennai  22.0  55740           0
# 96          172   Neha Desai         HR  Chennai  22.0  52250           0
# 97          115   Neha Reddy  Marketing  Chennai  43.0    NaN          12
# 98          193  Priya Nayak         HR      NaN  23.0  56821           3
# 99          152  Kavya Joshi  Marketing    Delhi  44.0  69499          10
#
#     performance_score  projects_completed joining_date
# 95                  5                  22   2020-04-22
# 96                  5                   7   2020-11-14
# 97                  4                  10   2019-06-06
# 98                  9                  16   2019-08-07
# 99                  7                   4   2022-03-25

# %%
df.sample()
# Out:
#     employee_id              name department     city   age salary  \
# 40          150  Vivek Chatterjee         HR  Kolkata  22.0  51391
#
#     experience  performance_score  projects_completed joining_date
# 40           0                  7                   8   2019-11-20

# %%
df.shape
## (100, 10)--> output
# Out:
# (100, 10)

# %%
df.dtypes ## what kind of data stored in each column
# Out:
# employee_id             int64
# name                   object
# department             object
# city                   object
# age                   float64
# salary                 object
# experience              int64
# performance_score       int64
# projects_completed      int64
# joining_date           object
# dtype: object

# %%
df.info() ## what is the overall structure and where are values  missing
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   employee_id         100 non-null    int64
#  1   name                100 non-null    object
#  2   department          92 non-null     object
#  3   city                90 non-null     object
#  4   age                 94 non-null     float64
#  5   salary              92 non-null     object
#  6   experience          100 non-null    int64
#  7   performance_score   100 non-null    int64
#  8   projects_completed  100 non-null    int64
#  9   joining_date        100 non-null    object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 7.9+ KB

# %%
df.describe() ## used to taking basics stats in our table
# Out:
#        employee_id        age  experience  performance_score  \
# count   100.000000  94.000000  100.000000           100.0000
# mean    148.740000  30.861702    4.830000             5.7500
# std      27.420637   6.483397    3.755279             1.7019
# min     101.000000  22.000000    0.000000             2.0000
# 25%     125.750000  25.250000    2.000000             5.0000
# 50%     149.500000  31.000000    4.500000             6.0000
# 75%     171.250000  35.750000    8.000000             7.0000
# max     196.000000  45.000000   17.000000            10.0000
#
#        projects_completed
# count          100.000000
# mean             9.970000
# std              5.332301
# min              0.000000
# 25%              6.000000
# 50%              9.500000
# 75%             13.250000
# max             24.000000

# %%
df.isnull()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    2 non-null      object
#  1   Salary  2 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 164.0+ bytes

# %%
df.isnull()
# Out:
#     Name  Salary
# 0  False   False
# 1  False   False

# %%
import pandas as pd
df = pd.read_csv("student_info - student_info.csv")
df.head(20)
# Out:
#    Student_ID             Name   Age  Gender    Department  Semester  \
# 0      STU001     Arjun Sharma   NaN  Female  Data Science         4
# 1      STU002     Arjun Shetty  24.0  Female           ISE         2
# 2      STU003      Aarav Reddy  21.0    Male           CSE         8
# 3      STU004       Rahul Nair  21.0  Female           CSE         6
# 4      STU005     Ananya Singh  21.0    Male           EEE         2
# 5      STU006     Aadhya Reddy  20.0    Male           EEE         7
# 6      STU007       Kavya Iyer  23.0    Male    Mechanical         6
# 7      STU008       Riya Naidu  25.0  Female  Data Science         1
# 8      STU009      Rahul Joshi  24.0    Male           ISE         2
# 9      STU010     Aadhya Singh  18.0    Male           EEE         2
# 10     STU011       Diya Patel  24.0  Female           ISE         4
# 11     STU012         Sai Nair  21.0    Male  Data Science         2
# 12     STU013   Rahul Kulkarni  19.0    Male           EEE         4
# ...

# %%
df[["CGPA","Age"]].isnull().sum()
# Out:
# CGPA    16
# Age     12
# dtype: int64

# %%
import pandas as pd 
df = pd.read_csv("student_info - student_info.csv")
df
# Out:
#     Student_ID          Name   Age  Gender    Department  Semester  \
# 0       STU001  Arjun Sharma   NaN  Female  Data Science         4
# 1       STU002  Arjun Shetty  24.0  Female           ISE         2
# 2       STU003   Aarav Reddy  21.0    Male           CSE         8
# 3       STU004    Rahul Nair  21.0  Female           CSE         6
# 4       STU005  Ananya Singh  21.0    Male           EEE         2
# ..         ...           ...   ...     ...           ...       ...
# 250     STU149   Kiran Joshi  25.0  Female    Mechanical         4
# 251     STU220  Vivaan Gupta  19.0    Male           NaN         7
# 252     STU095   Kiran Joshi  19.0  Female    Mechanical         2
# 253     STU085    Ananya Rao  23.0  Female           ISE         6
# 254     STU004    Rahul Nair  21.0  Female           CSE         6
#
#      Attendance_Percentage  Internal_Marks  CGPA       City Scholarship
# 0                     97.8            42.0  7.79  Mangaluru         Yes
# ...

# %%
df.dropna()
df
df = df.dropna()
df
# Out:
#     Student_ID          Name   Age  Gender  Department  Semester  \
# 1       STU002  Arjun Shetty  24.0  Female         ISE         2
# 2       STU003   Aarav Reddy  21.0    Male         CSE         8
# 3       STU004    Rahul Nair  21.0  Female         CSE         6
# 4       STU005  Ananya Singh  21.0    Male         EEE         2
# 8       STU009   Rahul Joshi  24.0    Male         ISE         2
# ..         ...           ...   ...     ...         ...       ...
# 245     STU246   Diya Shetty  19.0  Female       Civil         1
# 247     STU248    Meera Nair  24.0    Male         ECE         3
# 250     STU149   Kiran Joshi  25.0  Female  Mechanical         4
# 253     STU085    Ananya Rao  23.0  Female         ISE         6
# 254     STU004    Rahul Nair  21.0  Female         CSE         6
#
#      Attendance_Percentage  Internal_Marks  CGPA       City Scholarship
# 1                     62.0            21.7  9.26    Chennai         Yes
# ...

# %%
x.shape
# Out:
# (157, 11)

# %%
x.isnull()
# Out:
#      Student_ID   Name    Age  Gender  Department  Semester  \
# 1         False  False  False   False       False     False
# 2         False  False  False   False       False     False
# 3         False  False  False   False       False     False
# 4         False  False  False   False       False     False
# 8         False  False  False   False       False     False
# ..          ...    ...    ...     ...         ...       ...
# 245       False  False  False   False       False     False
# 247       False  False  False   False       False     False
# 250       False  False  False   False       False     False
# 253       False  False  False   False       False     False
# 254       False  False  False   False       False     False
#
#      Attendance_Percentage  Internal_Marks   CGPA   City  Scholarship
# 1                    False           False  False  False        False
# 2                    False           False  False  False        False
# ...

# %%
x.isnull().sum()
# Out:
# Student_ID               0
# Name                     0
# Age                      0
# Gender                   0
# Department               0
# Semester                 0
# Attendance_Percentage    0
# Internal_Marks           0
# CGPA                     0
# City                     0
# Scholarship              0
# dtype: int64

# %%
x[x["Age"].isnull()]
# Out:
# Empty DataFrame
# Columns: [Student_ID, Name, Age, Gender, Department, Semester, Attendance_Percentage, Internal_Marks, CGPA, City, Scholarship]
# Index: []

# %%
df[df["Age"].isnull()]
# Out:
# Empty DataFrame
# Columns: [Student_ID, Name, Age, Gender, Department, Semester, Attendance_Percentage, Internal_Marks, CGPA, City, Scholarship]
# Index: []

# %%
df.dropna(subset=['CGPA','Age'])
# Out:
#     Student_ID          Name   Age  Gender  Department  Semester  \
# 1       STU002  Arjun Shetty  24.0  Female         ISE         2
# 2       STU003   Aarav Reddy  21.0    Male         CSE         8
# 3       STU004    Rahul Nair  21.0  Female         CSE         6
# 4       STU005  Ananya Singh  21.0    Male         EEE         2
# 8       STU009   Rahul Joshi  24.0    Male         ISE         2
# ..         ...           ...   ...     ...         ...       ...
# 245     STU246   Diya Shetty  19.0  Female       Civil         1
# 247     STU248    Meera Nair  24.0    Male         ECE         3
# 250     STU149   Kiran Joshi  25.0  Female  Mechanical         4
# 253     STU085    Ananya Rao  23.0  Female         ISE         6
# 254     STU004    Rahul Nair  21.0  Female         CSE         6
#
#      Attendance_Percentage  Internal_Marks  CGPA       City Scholarship
# 1                     62.0            21.7  9.26    Chennai         Yes
# ...

# %%
df["Age"] = df["Age"].fillna(0)
df["Age"]
# Out:
# C:\Users\samee\AppData\Local\Temp\ipykernel_19676\116719855.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Age"] = df["Age"].fillna(0)
# 1      24.0
# 2      21.0
# 3      21.0
# 4      21.0
# 8      24.0
#        ...
# 245    19.0
# 247    24.0
# 250    25.0
# 253    23.0
# 254    21.0
# Name: Age, Length: 157, dtype: float64
