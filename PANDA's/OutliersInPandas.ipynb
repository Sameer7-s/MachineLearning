# %%
import pandas as pd 
df = pd.read_csv("student_information_with_outliers.csv")
df.head()
# Out:
#   Student_ID           Name   Age  Gender    Department  Semester  \
# 0     STU086    Diya Shetty  19.0    Male          AIML         7
# 1     STU124    Kiran Reddy  19.0    Male           EEE         1
# 2     STU250    Meera Joshi  21.0  Female          AIML         8
# 3     STU030  Aadhya Sharma  24.0    Male  Data Science         8
# 4     STU076   Aditya Gupta  19.0    Male           EEE         2
# 5     STU047    Rahul Verma  25.0    Male           ECE         2
# 6     STU235   Arjun Sharma  19.0  Female  Data Science         5
# 7     STU201    Aditya Iyer  22.0    Male         Civil         3
# 8     STU019    Nisha Gupta  21.0    Male    Mechanical         5
# 9     STU219      Nisha Das  22.0    Male           ISE         6
#
#    Attendance_Percentage  Internal_Marks  CGPA       City Scholarship
# 0                   95.0           -15.0  8.41    Chennai         Yes
# 1                   72.3            25.0  9.73   Hubballi         Yes
# ...
