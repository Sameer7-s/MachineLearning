# %% [markdown]
# NUMPY EXCERCISE

# %%
import numpy as np 
data = np.array([1,2,3]) ## 1d 
data = np.array([[123,456,456] , [231,5,5]])
print(data)
# Out:
# [[123 456 456]
#  [231   5   5]]

# %%
SUDUKO

# %%
##GENERAL QUESTION 
## COLUMNS = [ AGE , MATH MARKS , SCIENCE MARKS]
data = np.array([
    [18 , 85 , 78],
    [19 , 92 , 88],
    [17 , 76 , 95],
    [18 , 65 , 70],
    [20 , 90 , 85],
    
])
